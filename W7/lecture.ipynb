# %%
from flask import Flask, render_template, request

app = Flask(__name__, template_folder='.')

@app.route('/')
def home():
    return render_template('flask.html')

@app.route('/<name>')
def show_name(name):
    return render_template('flask.html', name=name)

app.run(host = "0.0.0.0", debug = False, threaded = False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.140.13.196:5000
# Press CTRL+C to quit
# 10.140.13.196 - - [05/Mar/2026 16:21:25] "GET / HTTP/1.1" 200 -
# 10.140.13.196 - - [05/Mar/2026 16:21:32] "GET /young HTTP/1.1" 200 -
# 10.140.13.196 - - [05/Mar/2026 16:21:54] "GET /wu HTTP/1.1" 200 -
# 10.140.13.196 - - [05/Mar/2026 16:22:24] "GET / HTTP/1.1" 200 -
# 10.140.13.196 - - [05/Mar/2026 16:24:08] "GET / HTTP/1.1" 200 -
# 10.140.13.196 - - [05/Mar/2026 16:24:24] "GET /peter1 HTTP/1.1" 200 -
