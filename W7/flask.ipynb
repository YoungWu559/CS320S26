# %%
from flask import Flask, request, redirect, jsonify, Response
import matplotlib.pyplot as plt
import time
import pandas

# %%
app = Flask("app")

visitor = 0
visitors = []

@app.route("/")
def index():
    return redirect("visit")

@app.route("/visit")
def home():
    global visitor, visitors
    visitor = visitor + 1
    visitors.append([visitor, "-", request.remote_addr])
    return "Hello, visitor " + str(visitor)

@app.route("/visit/<int:x>")
def hello(x):
    global visitor, visitors
    visitor = visitor + 1
    visitors.append([visitor, x, request.remote_addr])
    return "Hello, " + x

@app.route("/visitors")
def display():
    df = pandas.DataFrame(visitors, columns = ["#", "Name", "IP"])
    return df.to_html()

app.run(host = "0.0.0.0", debug = False, threaded = False)
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.141.76.17:5000
# Press CTRL+C to quit
# 10.141.76.17 - - [03/Mar/2026 17:21:40] "GET / HTTP/1.1" 302 -
# 10.141.76.17 - - [03/Mar/2026 17:21:40] "GET /visit HTTP/1.1" 200 -
# 10.141.76.17 - - [03/Mar/2026 17:21:43] "GET /visit HTTP/1.1" 200 -
# 10.141.76.17 - - [03/Mar/2026 17:21:50] "GET /visit/peter HTTP/1.1" 200 -
# 10.141.76.17 - - [03/Mar/2026 17:22:50] "GET /visitors HTTP/1.1" 200 -
